# %%
import os

os.environ['OPENAI_API_KEY'] = 'sk-proj-ox3fGo8JnYhWGiZc9qppT3BlbkFJse51xSixMirTcOF9xeth'

# %%
from langchain.llms import OpenAI

llm = OpenAI(temperature=0.6)
name = llm("I want to open a restaurant for Indian food. Suggest a fancy name for this")
print(name)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[19], line 4
#       1 from langchain.llms import OpenAI
#       3 llm = OpenAI(temperature=0.6)
# ----> 4 name = llm("I want to open a restaurant for Indian food. Suggest a fancy name for this")
#       5 print(name)
#
# File ~\anaconda31\Lib\site-packages\langchain_core\_api\deprecation.py:168, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     166     warned = True
#     167     emit_warning()
# --> 168 return wrapped(*args, **kwargs)
#
# File ~\anaconda31\Lib\site-packages\langchain_core\language_models\llms.py:1086, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1079 if not isinstance(prompt, str):
#    1080     raise ValueError(
#    1081         "Argument `prompt` is expected to be a string. Instead found "
# ...

# %%
# !pip install langchain
# !pip install OpenAI

# %%
# !pip install langchain langchain_community
# Out:
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.2 MB 991.0 kB/s eta 0:00:03
#     --------------------------------------- 0.0/2.2 MB 991.0 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/2.2 MB 1.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.3/2.2 MB 1.7 MB/s eta 0:00:02
#    --------- ------------------------------ 0.5/2.2 MB 2.4 MB/s eta 0:00:01
#    ------------- -------------------------- 0.8/2.2 MB 2.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.0/2.2 MB 3.2 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.2 MB 3.3 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.2 MB 3.1 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.2 MB 3.1 MB/s eta 0:00:01
#    --------------------- ------------------ 1.2/2.2 MB 2.6 MB/s eta 0:00:01
# ...

# %%
# !pip install openai langchain langchain_community

# %%
from langchain.llms import OpenAI

llm = OpenAI(temperature=0.6)
name = llm("I want to open a restaurant for Indian food. Suggest a fancy name for this")
print(name)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[16], line 4
#       1 from langchain.llms import OpenAI
#       3 llm = OpenAI(temperature=0.6)
# ----> 4 name = llm("I want to open a restaurant for Indian food. Suggest a fancy name for this")
#       5 print(name)
#
# File ~\anaconda31\Lib\site-packages\langchain_core\_api\deprecation.py:168, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     166     warned = True
#     167     emit_warning()
# --> 168 return wrapped(*args, **kwargs)
#
# File ~\anaconda31\Lib\site-packages\langchain_core\language_models\llms.py:1086, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1079 if not isinstance(prompt, str):
#    1080     raise ValueError(
#    1081         "Argument `prompt` is expected to be a string. Instead found "
# ...

# %%
# %%capture
# !pip install -q langchain
# !pip install -q openai
